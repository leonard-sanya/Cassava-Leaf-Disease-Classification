jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-616.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-646.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-690.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-458.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-93.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-51.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-221.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-762.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-83.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-698.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-744.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-659.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-717.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-45.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-31.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-686.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-316.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-39.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-737.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-292.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-146.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-224.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-375.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-149.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-758.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-139.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-76.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-412.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-621.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-734.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-105.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-270.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-296.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-40.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-212.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-368.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-58.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-500.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-480.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-716.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-508.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-759.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-524.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-44.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-347.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-143.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-451.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-614.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-657.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-109.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-712.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-243.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-1.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-345.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-48.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-394.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-429.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-344.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-755.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-666.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-329.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-141.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-419.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-182.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-285.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-304.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-361.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-177.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-27.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-252.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-476.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-515.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-54.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-81.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-358.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-511.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-265.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-641.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-190.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-453.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-206.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-341.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-473.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-561.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-756.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-289.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-548.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-69.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-414.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-624.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-226.jpg
# /kaggle/input/ammi-2024-computer-vision/train/train/cgm/train-cgm-741.jpg

# %%
#Imports
import os
import sys
import glob
import torch
import timm
import torchvision

import numpy    as np
import datetime as dt
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot   as plt

from PIL               import Image
from torch.utils.data  import Dataset
from torch.autograd    import Variable
from torch.optim       import lr_scheduler

from torch.utils.data  import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision       import transforms, datasets, models
from os                import listdir, makedirs, getcwd, remove
from os.path           import isfile, join, abspath, exists, isdir, expanduser

# %%
data_path = "../input/ammi-2024-computer-vision/"

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
train_path = "/kaggle/input/ammi-2024-computer-vision/train/train"
test_path = "/kaggle/input/ammi-2024-computer-vision/test/test"
# extraimage_path = join(data_path, "extraimages/extraimages")

# %%
# Transformations for both the training and testing data
mean=[0.485, 0.456, 0.406]
std=[0.229, 0.224, 0.225]

# Do data transforms here, Try many others
train_transforms = transforms.Compose([transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor()])

test_transforms = transforms.Compose([ transforms.Resize(255),
                                       transforms.CenterCrop(224),
                                       transforms.ToTensor()])

normalize = transforms.Normalize(mean=mean, std=std)

class CassavaDataset(Dataset):
    def __init__(self, path, transform=None):
        self.classes = os.listdir(path)
        self.path = [f"{path}/{className}" for className in self.classes]
        self.file_list = [glob.glob(f"{x}/*") for x in self.path]
        self.transform = transform

        files = []
        for i, className in enumerate(self.classes):
            for fileName in self.file_list[i]:
                files.append([i, className, fileName])
        self.file_list = files
        files = None

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        fileName = self.file_list[idx][2]
        classCategory = self.file_list[idx][0]
        im = Image.open(fileName)
        if self.transform:
            im = self.transform(im)
            
        return im.view(3, 224, 224), classCategory
    
train_data = CassavaDataset(train_path, transform=train_transforms)
test_data = CassavaDataset(test_path, transform=test_transforms) 


validation_split = .2
shuffle_dataset = True
random_seed= 42

# Creating data indices for training and validation splits:
dataset_size = len(train_data)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))

if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)

train_indices, val_indices = indices[split:], indices[:split]


# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
valid_sampler = SubsetRandomSampler(val_indices)


train_set = torch.utils.data.DataLoader(train_data, batch_size=32,
                                             sampler=train_sampler)
test_set = torch.utils.data.DataLoader(train_data, batch_size=32,
                                             sampler=valid_sampler)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=32)

train_len = len(train_set)*32
valid_len = len(test_set)*32

# %%
# for class_name, class_index in train_data.class_to_idx.items():
#     print(f"Class: {class_name}, Label: {class_index}")

# %%
class Classifier(nn.Module):
    def __init__(self, num_classes, weights=models.ResNet34_Weights.DEFAULT):
        super().__init__()
        
        # Load the pre-trained ResNet34 model
        self.resnet = models.resnet34(weights=weights)
        
        # Modify the final fully connected layer to match the number of classes
        num_ftrs = self.resnet.fc.in_features
        self.resnet.fc = nn.Linear(num_ftrs, num_classes)
    
    def forward(self, x):
        return self.resnet(x)

# Example usage:

# %%
num_classes = 5
model = Classifier(num_classes)
print(model)
# Out:
# Classifier(
#   (resnet): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Linear(in_features=512, out_features=5, bias=True)
#   )
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(),lr = 0.001,momentum= 0.9)

# %%
def train(model, criterion, data_loader1, optimizer, num_epochs):
    """Simple training loop for a PyTorch model.""" 
    model = model.to(device)
    # Make sure model is in training mode.
    #model.train()

    model.train()
    for epoch in range(num_epochs):
        total_correct = 0
        running_loss = 0

        # Training step
        for i, (inputs, labels) in enumerate(data_loader1):
            inputs , labels  = inputs.to(device),labels.to(device)

            output = model(inputs)
            #print(output.logits)
            output_idx = torch.argmax(output,dim =-1)
            total_correct +=(labels==output_idx).sum().item()
            optimizer.zero_grad()
            loss = criterion(output, labels)
            running_loss+=loss.item()*inputs.size(0)
            loss.backward()
            optimizer.step()

        # Print out progress at the end of epoch.
        print(f"Epoch {epoch}, Train Loss: {running_loss/train_len}, Accuracy: {(total_correct/train_len)*100}%")
    print("Finished Training")

# %%
def test(model, test_set):

    with torch.no_grad():
        model.eval()
        total_loss = 0
        total_correct = 0

        # Testing step
        for inputs, labels in test_set:
            inputs , labels  = inputs.to(device),labels.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, labels)
            total_loss +=loss.item()*inputs.size(0)
            output_idx = torch.argmax(outputs,dim =-1)
            total_correct +=(labels==output_idx).sum().item()

        print(f"Accuracy: {(total_correct/valid_len)*100}%  Loss: {total_loss/valid_len}")

# %%
num_epochs = 20
train(model, criterion, train_set, optimizer, num_epochs=num_epochs)
# Out:
# Epoch 0, Train Loss: 0.9094042034268799, Accuracy: 65.97711267605634%
# Epoch 1, Train Loss: 0.629168664669277, Accuracy: 77.2887323943662%
# Epoch 2, Train Loss: 0.5443664183315466, Accuracy: 80.1056338028169%
# Epoch 3, Train Loss: 0.5004872249990282, Accuracy: 82.13028169014085%
# Epoch 4, Train Loss: 0.45085122776021, Accuracy: 83.84683098591549%
# Epoch 5, Train Loss: 0.4414305621233415, Accuracy: 84.17693661971832%
# Epoch 6, Train Loss: 0.4158897472506153, Accuracy: 84.92517605633803%
# Epoch 7, Train Loss: 0.393517202382881, Accuracy: 85.40933098591549%
# Epoch 8, Train Loss: 0.3838431708593394, Accuracy: 86.39964788732394%
# Epoch 9, Train Loss: 0.3776090868591318, Accuracy: 86.72975352112677%
# Epoch 10, Train Loss: 0.3651479512492431, Accuracy: 86.31161971830986%
# Epoch 11, Train Loss: 0.3334926702606846, Accuracy: 87.9181338028169%
# Epoch 12, Train Loss: 0.3250945440172152, Accuracy: 88.18221830985915%
# Epoch 13, Train Loss: 0.3188146345225543, Accuracy: 88.05017605633803%
# Epoch 14, Train Loss: 0.2937133429558869, Accuracy: 88.9524647887324%
# Epoch 15, Train Loss: 0.28549309048316324, Accuracy: 89.67869718309859%
# Epoch 16, Train Loss: 0.2751398241417122, Accuracy: 90.05281690140845%
# Epoch 17, Train Loss: 0.3002522132510293, Accuracy: 88.51232394366197%
# Epoch 18, Train Loss: 0.27881613147484374, Accuracy: 89.70070422535211%
# Epoch 19, Train Loss: 0.25803418882833923, Accuracy: 90.71302816901408%
# Finished Training

# %%
test(model,test_set)
# Out:
# Accuracy: 83.33333333333334%  Loss: 0.48423856295024353

# %%
train_data.classes
# Out:
# ['cmd', 'cbb', 'cbsd', 'healthy', 'cgm']

# %%
# Make submission here
sample_path = "/kaggle/input/ammi-2024-computer-vision/sample_submission_file.csv"
import pandas as pd

def test_mode(model, data_loader):
    """Measures the accuracy of a model on a data set.""" 
    # Make sure the model is in evaluation mode.
    preds = []
    model.eval()
    # We do not need to maintain intermediate activations while testing.
    with torch.no_grad():
        
        # Loop over test data.
        for features, _ in data_loader:
          
            # Forward pass.
            output = model(features.to(device))
            
            # Get the label corresponding to the highest predicted probability.
            pred = output.argmax(dim=1, keepdim=True)
            preds.append(pred.cpu().data.numpy())
            
    return preds

preds = test_mode(model, test_loader)
preds = [item.item() for sublist in preds for item in sublist]

# Extract filenames from the ImageFolder object
name = [os.path.basename(img_path) for _, _, img_path in test_data.file_list]
sample = pd.read_csv(sample_path)
mapping = {0: 'cmd', 1: 'cbb', 2: 'cbsd', 3: 'healthy', 4: 'cgm'}
new_preds = [mapping[pred] for pred in preds]
sample['Category'] = name
sample['Id'] = new_preds
sample["Category"],sample["Id"] = sample["Id"],sample["Category"]


sample.to_csv('submission7.csv', index=False)
sample.head()
# Out:
#   Category                 Id
# 0      cgm  test-img-1448.jpg
# 1      cmd   test-img-768.jpg
# 2      cmd  test-img-3481.jpg
# 3      cmd  test-img-1475.jpg
# 4      cgm  test-img-2498.jpg

# %%
# sample_path ="/kaggle/input/ammi-2024-computer-vision/sample_submission_file.csv"
# #sample_path = os.path.join(sample_path, "sample_submission_file.csv")
# import pandas as pd
# from tqdm import tqdm
# def predict(model, loader):
#     test_dataloader = loader
#     preds = []

#     for test_images, _ in tqdm(test_dataloader):
#         test_images = test_images.to(device)
#         #test_labels = test_labels.to(device)

#         output = model(test_images)

#         _, predicted = torch.max(output, 1)
#         preds.extend(predicted.cpu().data.numpy())


#     return preds

# name = [test_data.file_list[i][-1].split('/')[-1] for i in range(len(test_data.file_list)) ]
# sample = pd.read_csv(sample_path)
# sample['Id'] = name
# preds = predict(model, test_loader)
# mapping = {0: 'cgm', 1: 'cmd', 2: 'healthy', 3: 'cbb', 4: 'cbsd'}
# new_preds = [mapping[pred] for pred in preds]
# sample['Category'] = new_preds
# sample.to_csv('submission_resnet34.csv', index=False)
# sample.head()

# %%
2**8
# Out:
# 256
